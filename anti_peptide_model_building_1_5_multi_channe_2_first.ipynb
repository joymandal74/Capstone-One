# %%
from keras.layers import Dense
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPool1D
from keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
from keras.layers import Dropout
from keras.layers import SpatialDropout1D
from keras.optimizers import Adam,SGD
from keras.layers import BatchNormalization
from keras.layers import GaussianDropout
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
X_train = np.load('new_X_train.npy')
y_train = np.load('train_labels.npy')

#shuffling the training instances
p = np.random.permutation(len(X_train))
X_train = X_train[p,:,:]
y_train = y_train[p]

#set the channels that you want to use
starting_channel = 0
ending_channel = 3
end_index = ending_channel + 1
number_of_channels_used = (ending_channel - starting_channel) + 1

X_train = X_train[:,starting_channel:end_index,:]

X_train_temp = X_train[0:448,:,:]
X_val = X_train[448:,:,:]
X_train = X_train_temp

y_train_temp = y_train[0:448]
y_val = y_train[448:]
y_train = y_train_temp




print(X_train.shape)
print(y_train.shape)
# Out:
# (448, 4, 94)
# (448,)

# %%
#lets create separate heads for hydrophobicity, alpha and beta

# %%
# don't run it right now
X_train = np.load('X_train.npy')
y_train = np.load('train_labels.npy')

p = np.random.permutation(len(X_train))
X_train = X_train[p,:,:]
y_train = y_train[p]

#let us create the validation split by hand

X_train_temp = X_train[0:450,:,:]
X_val = X_train[450:500,:,:]
X_train = X_train_temp

y_train_temp = y_train[0:450]
y_val = y_train[450:500]
y_train = y_train_temp


X_train_1 = X_train[:,0:2,:]
X_train_2 = X_train[:,2:4,:]
X_train_3 = X_train[:,4:6,:]
X_train_4 = X_train[:,6:8,:]
X_train_5 = X_train[:,8:10,:]

X_val_1 = X_val[:,0:2,:]
X_val_2 = X_val[:,2:4,:]
X_val_3 = X_val[:,4:6,:]
X_val_4 = X_val[:,6:8,:]
X_val_5 = X_val[:,8:10,:]

# %%
visibile = Input(shape=(number_of_channels_used,94))
#dropout_1 = SpatialDropout1D(0.3)(visibile)

conv = Conv1D(filters=20,kernel_size=3,padding='same',data_format='channels_first',activation='relu')(visibile)
#bn_11 = BatchNormalization()(conv_11)
#conv_12 = Conv1D(filters=30,kernel_size=3,padding='same',data_format='channels_first',activation='relu')(conv_11)
#bn_12 = BatchNormalization()(conv_12)
#spatial_dropout_1 = SpatialDropout1D(0.3)(conv_11)
#spatial_dropout_1 = SpatialDropout1D(0.3)(conv_11)
conv = MaxPool1D(pool_size=2,strides=2,data_format='channels_first')(conv)
conv = Dropout(0.25)(conv)

#conv_221 = Conv1D(filters=10,kernel_size=3,padding='same',data_format='channels_first',activation='relu')(max_pool_1)
#bn_11 = BatchNormalization()(conv_11)
#conv_222 = Conv1D(filters=30,kernel_size=3,padding='same',data_format='channels_first',activation='relu')(conv_221)
#bn_12 = BatchNormalization()(conv_12)
#spatial_dropout_221 = SpatialDropout1D(0.3)(conv_221)
#max_pool_221 = MaxPool1D(pool_size=2,strides=2,data_format='channels_first',padding='same')(spatial_dropout_221)

conv = Conv1D(filters=15,kernel_size=6,padding='same',data_format='channels_first',activation='relu')(conv)
#conv_21 = Conv1D(filters=30,kernel_size=6,padding='same',data_format='channels_first',activation='relu')(max_pool_1)
#bn_21 = BatchNormalization()(conv_21)
#conv_22 = Conv1D(filters=30,kernel_size=6,padding='same',data_format='channels_first',activation='relu')(conv_21)
#bn_22 = BatchNormalization()(conv_22)
#conv = SpatialDropout1D(0.3)(conv)
conv = MaxPool1D(pool_size=2,strides=2,data_format='channels_first')(conv)
conv = Dropout(0.25)(conv)

conv = Conv1D(filters=15,kernel_size=9,padding='same',data_format='channels_first',activation='relu')(conv)
#conv_31 = Conv1D(filters=30,kernel_size=9,padding='same',data_format='channels_first',activation='relu')(max_pool_2)
#conv_32 = Conv1D(filters=30,kernel_size=9,padding='same',data_format='channels_first',activation='relu')(conv_31)
#conv = SpatialDropout1D(0.3)(conv)
conv = MaxPool1D(pool_size=2,strides=2,data_format='channels_first')(conv)
conv = Dropout(0.25)(conv)

conv = Conv1D(filters=15,kernel_size=12,padding='same',data_format='channels_first',activation='relu')(conv)
#conv_41 = Conv1D(filters=30,kernel_size=12,padding='same',data_format='channels_first',activation='relu')(conv_32)
#conv_42 = Conv1D(filters=30,kernel_size=12,padding='same',data_format='channels_first',activation='relu')(conv_41)
#conv = SpatialDropout1D(0.3)(conv)
conv = MaxPool1D(pool_size=2,strides=1,data_format='channels_first')(conv)
conv = Dropout(0.25)(conv)


conv = Flatten()(conv)
#dropout_2 = Dropout(0.2)(flat_1)
#dropout_2 = GaussianDropout(0.2)(flat_1)

dense_1 = Dense(30,activation='relu')(conv)
#bn_3 = BatchNormalization()(dense_1)
dropout_3 = Dropout(0.25)(dense_1)
#dropout_3 = GaussianDropout(0.2)(dense_1)

dense_1 = Dense(30,activation='relu')(conv)
#bn_3 = BatchNormalization()(dense_1)
dropout_3 = Dropout(0.25)(dense_1)

dense_2 = Dense(15,activation='relu')(dropout_3)
#bn_4 = BatchNormalization()(dense_2)
dropout_4 = Dropout(0.25)(dense_2)
#dropout_4 = GaussianDropout(0.2)(dense_2)

output = Dense(1,activation='sigmoid')(dropout_4)

model = Model(inputs=visibile, outputs=output)

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 4, 94)             0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 20, 94)            260
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 20, 47)            0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 20, 47)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 15, 47)            1815
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 15, 23)            0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 15, 23)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 15, 23)            2040
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 15, 11)            0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 11)            0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 15, 11)            2715
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 15, 10)            0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 15, 10)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 150)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                4530
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                465
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 11,841
# Trainable params: 11,841
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
early_stopping_monitor = EarlyStopping(patience=1000)

# %%
optimizer = Adam(lr=0.00005)
#optimizer = SGD(lr= 0.00001, momentum=0.9)


model.compile(optimizer=optimizer, loss='binary_crossentropy',metrics=['accuracy'])
filepath = "model_21.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max',save_weights_only=False)
callback_list = [checkpoint]
model.fit(x=X_train,y=y_train,validation_data=(X_val,y_val), epochs=9000, callbacks=callback_list, batch_size=16)
# Out:
# Train on 448 samples, validate on 50 samples
# Epoch 1/9000
# 448/448 [==============================] - 1s 2ms/step - loss: 0.8140 - acc: 0.5179 - val_loss: 0.6989 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to model_21.h5
# Epoch 2/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.7437 - acc: 0.5536 - val_loss: 0.6906 - val_acc: 0.5200
#
# Epoch 00002: val_acc improved from 0.50000 to 0.52000, saving model to model_21.h5
# Epoch 3/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.7656 - acc: 0.4799 - val_loss: 0.6885 - val_acc: 0.5600
#
# Epoch 00003: val_acc improved from 0.52000 to 0.56000, saving model to model_21.h5
# Epoch 4/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.7512 - acc: 0.4754 - val_loss: 0.6869 - val_acc: 0.6400
#
# Epoch 00004: val_acc improved from 0.56000 to 0.64000, saving model to model_21.h5
# Epoch 5/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.7284 - acc: 0.4978 - val_loss: 0.6857 - val_acc: 0.5800
#
# Epoch 00005: val_acc did not improve from 0.64000
# Epoch 6/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7289 - acc: 0.4911 - val_loss: 0.6852 - val_acc: 0.6200
#
# Epoch 00006: val_acc did not improve from 0.64000
# Epoch 7/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7106 - acc: 0.5089 - val_loss: 0.6848 - val_acc: 0.5600
#
# Epoch 00007: val_acc did not improve from 0.64000
# Epoch 8/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7124 - acc: 0.5312 - val_loss: 0.6844 - val_acc: 0.6200
#
# Epoch 00008: val_acc did not improve from 0.64000
# Epoch 9/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7116 - acc: 0.4777 - val_loss: 0.6848 - val_acc: 0.5600
#
# Epoch 00009: val_acc did not improve from 0.64000
# Epoch 10/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7299 - acc: 0.4821 - val_loss: 0.6855 - val_acc: 0.5600
#
# Epoch 00010: val_acc did not improve from 0.64000
# Epoch 11/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7051 - acc: 0.5290 - val_loss: 0.6861 - val_acc: 0.5600
#
# Epoch 00011: val_acc did not improve from 0.64000
# Epoch 12/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7062 - acc: 0.5179 - val_loss: 0.6861 - val_acc: 0.5400
#
# Epoch 00012: val_acc did not improve from 0.64000
# Epoch 13/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7130 - acc: 0.4844 - val_loss: 0.6866 - val_acc: 0.5400
#
# Epoch 00013: val_acc did not improve from 0.64000
# Epoch 14/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.7183 - acc: 0.4955 - val_loss: 0.6866 - val_acc: 0.5600
#
# Epoch 00014: val_acc did not improve from 0.64000
# Epoch 15/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.7102 - acc: 0.5156 - val_loss: 0.6864 - val_acc: 0.5400
#
# Epoch 00015: val_acc did not improve from 0.64000
# Epoch 16/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7083 - acc: 0.4732 - val_loss: 0.6868 - val_acc: 0.5200
#
# Epoch 00016: val_acc did not improve from 0.64000
# Epoch 17/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.7209 - acc: 0.4978 - val_loss: 0.6872 - val_acc: 0.5200
#
# Epoch 00017: val_acc did not improve from 0.64000
# Epoch 18/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.7091 - acc: 0.4777 - val_loss: 0.6874 - val_acc: 0.5200
#
# Epoch 00018: val_acc did not improve from 0.64000
# Epoch 19/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7045 - acc: 0.4710 - val_loss: 0.6877 - val_acc: 0.5400
#
# Epoch 00019: val_acc did not improve from 0.64000
# Epoch 20/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7046 - acc: 0.5089 - val_loss: 0.6875 - val_acc: 0.5200
#
# Epoch 00020: val_acc did not improve from 0.64000
# Epoch 21/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6893 - acc: 0.5246 - val_loss: 0.6874 - val_acc: 0.5200
#
# Epoch 00021: val_acc did not improve from 0.64000
# Epoch 22/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6959 - acc: 0.5223 - val_loss: 0.6870 - val_acc: 0.5400
#
# Epoch 00022: val_acc did not improve from 0.64000
# Epoch 23/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6977 - acc: 0.5045 - val_loss: 0.6870 - val_acc: 0.5200
#
# Epoch 00023: val_acc did not improve from 0.64000
# Epoch 24/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7061 - acc: 0.4933 - val_loss: 0.6868 - val_acc: 0.5200
#
# Epoch 00024: val_acc did not improve from 0.64000
# Epoch 25/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7157 - acc: 0.4554 - val_loss: 0.6869 - val_acc: 0.5400
#
# Epoch 00025: val_acc did not improve from 0.64000
# Epoch 26/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6980 - acc: 0.5089 - val_loss: 0.6867 - val_acc: 0.5400
#
# Epoch 00026: val_acc did not improve from 0.64000
# Epoch 27/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.7046 - acc: 0.5067 - val_loss: 0.6869 - val_acc: 0.5400
#
# Epoch 00027: val_acc did not improve from 0.64000
# Epoch 28/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6977 - acc: 0.5045 - val_loss: 0.6869 - val_acc: 0.5400
#
# Epoch 00028: val_acc did not improve from 0.64000
# Epoch 29/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7013 - acc: 0.4821 - val_loss: 0.6868 - val_acc: 0.5400
#
# Epoch 00029: val_acc did not improve from 0.64000
# Epoch 30/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6900 - acc: 0.5402 - val_loss: 0.6869 - val_acc: 0.5400
#
# Epoch 00030: val_acc did not improve from 0.64000
# Epoch 31/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6970 - acc: 0.4866 - val_loss: 0.6870 - val_acc: 0.5600
#
# Epoch 00031: val_acc did not improve from 0.64000
# Epoch 32/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6923 - acc: 0.5268 - val_loss: 0.6868 - val_acc: 0.5400
#
# Epoch 00032: val_acc did not improve from 0.64000
# Epoch 33/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6936 - acc: 0.5112 - val_loss: 0.6863 - val_acc: 0.5400
#
# Epoch 00033: val_acc did not improve from 0.64000
# Epoch 34/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.7054 - acc: 0.4531 - val_loss: 0.6864 - val_acc: 0.5400
#
# Epoch 00034: val_acc did not improve from 0.64000
# Epoch 35/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6878 - acc: 0.5446 - val_loss: 0.6864 - val_acc: 0.5600
#
# Epoch 00035: val_acc did not improve from 0.64000
# Epoch 36/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6934 - acc: 0.5268 - val_loss: 0.6860 - val_acc: 0.5600
#
# Epoch 00036: val_acc did not improve from 0.64000
# Epoch 37/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.7030 - acc: 0.4933 - val_loss: 0.6862 - val_acc: 0.5600
#
# Epoch 00037: val_acc did not improve from 0.64000
# Epoch 38/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6881 - acc: 0.5446 - val_loss: 0.6859 - val_acc: 0.5400
#
# Epoch 00038: val_acc did not improve from 0.64000
# Epoch 39/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6955 - acc: 0.5290 - val_loss: 0.6861 - val_acc: 0.5400
#
# Epoch 00039: val_acc did not improve from 0.64000
# Epoch 40/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.7009 - acc: 0.4844 - val_loss: 0.6861 - val_acc: 0.5400
#
# Epoch 00040: val_acc did not improve from 0.64000
# Epoch 41/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6943 - acc: 0.4911 - val_loss: 0.6860 - val_acc: 0.5400
#
# Epoch 00041: val_acc did not improve from 0.64000
# Epoch 42/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.6942 - acc: 0.5312 - val_loss: 0.6861 - val_acc: 0.5400
#
# Epoch 00042: val_acc did not improve from 0.64000
# Epoch 43/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6900 - acc: 0.5156 - val_loss: 0.6858 - val_acc: 0.5400
# Epoch 00043: val_acc did not improve from 0.64000
# Epoch 44/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6924 - acc: 0.5134 - val_loss: 0.6857 - val_acc: 0.5400
#
# Epoch 00044: val_acc did not improve from 0.64000
# Epoch 45/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6867 - acc: 0.5491 - val_loss: 0.6855 - val_acc: 0.5400
#
# Epoch 00045: val_acc did not improve from 0.64000
# Epoch 46/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6882 - acc: 0.5580 - val_loss: 0.6852 - val_acc: 0.5400
#
# Epoch 00046: val_acc did not improve from 0.64000
# Epoch 47/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6973 - acc: 0.5045 - val_loss: 0.6852 - val_acc: 0.5600
#
# Epoch 00047: val_acc did not improve from 0.64000
# Epoch 48/9000
# 448/448 [==============================] - 0s 212us/step - loss: 0.6988 - acc: 0.4978 - val_loss: 0.6849 - val_acc: 0.5600
#
# Epoch 00048: val_acc did not improve from 0.64000
# Epoch 49/9000
# 448/448 [==============================] - 0s 216us/step - loss: 0.6939 - acc: 0.5379 - val_loss: 0.6848 - val_acc: 0.5600
#
# Epoch 00049: val_acc did not improve from 0.64000
# Epoch 50/9000
# 448/448 [==============================] - 0s 212us/step - loss: 0.6899 - acc: 0.5513 - val_loss: 0.6844 - val_acc: 0.5600
#
# Epoch 00050: val_acc did not improve from 0.64000
# Epoch 51/9000
# 448/448 [==============================] - 0s 218us/step - loss: 0.6909 - acc: 0.5268 - val_loss: 0.6841 - val_acc: 0.5400
#
# Epoch 00051: val_acc did not improve from 0.64000
# Epoch 52/9000
# 448/448 [==============================] - 0s 206us/step - loss: 0.6905 - acc: 0.5022 - val_loss: 0.6841 - val_acc: 0.5400
#
# Epoch 00052: val_acc did not improve from 0.64000
# Epoch 53/9000
# 448/448 [==============================] - 0s 211us/step - loss: 0.6910 - acc: 0.5580 - val_loss: 0.6837 - val_acc: 0.5400
#
# Epoch 00053: val_acc did not improve from 0.64000
# Epoch 54/9000
# 448/448 [==============================] - 0s 208us/step - loss: 0.6960 - acc: 0.5134 - val_loss: 0.6838 - val_acc: 0.5400
#
# Epoch 00054: val_acc did not improve from 0.64000
# Epoch 55/9000
# 448/448 [==============================] - 0s 225us/step - loss: 0.6864 - acc: 0.5871 - val_loss: 0.6837 - val_acc: 0.5400
#
# Epoch 00055: val_acc did not improve from 0.64000
# Epoch 56/9000
# 448/448 [==============================] - 0s 207us/step - loss: 0.6917 - acc: 0.5268 - val_loss: 0.6836 - val_acc: 0.5400
#
# Epoch 00056: val_acc did not improve from 0.64000
# Epoch 57/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.6867 - acc: 0.5379 - val_loss: 0.6835 - val_acc: 0.5400
#
# Epoch 00057: val_acc did not improve from 0.64000
# Epoch 58/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6909 - acc: 0.5357 - val_loss: 0.6833 - val_acc: 0.5400
#
# Epoch 00058: val_acc did not improve from 0.64000
# Epoch 59/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6926 - acc: 0.5312 - val_loss: 0.6834 - val_acc: 0.5400
#
# Epoch 00059: val_acc did not improve from 0.64000
# Epoch 60/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6886 - acc: 0.4933 - val_loss: 0.6833 - val_acc: 0.5400
#
# Epoch 00060: val_acc did not improve from 0.64000
# Epoch 61/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6932 - acc: 0.5357 - val_loss: 0.6834 - val_acc: 0.5600
#
# Epoch 00061: val_acc did not improve from 0.64000
# Epoch 62/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6913 - acc: 0.5357 - val_loss: 0.6838 - val_acc: 0.5600
#
# Epoch 00062: val_acc did not improve from 0.64000
# Epoch 63/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6868 - acc: 0.5379 - val_loss: 0.6837 - val_acc: 0.5600
#
# Epoch 00063: val_acc did not improve from 0.64000
# Epoch 64/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6877 - acc: 0.5491 - val_loss: 0.6835 - val_acc: 0.5600
#
# Epoch 00064: val_acc did not improve from 0.64000
# Epoch 65/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6869 - acc: 0.5513 - val_loss: 0.6830 - val_acc: 0.5800
#
# Epoch 00065: val_acc did not improve from 0.64000
# Epoch 66/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6959 - acc: 0.5179 - val_loss: 0.6828 - val_acc: 0.5800
#
# Epoch 00066: val_acc did not improve from 0.64000
# Epoch 67/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6922 - acc: 0.5246 - val_loss: 0.6830 - val_acc: 0.5800
#
# Epoch 00067: val_acc did not improve from 0.64000
# Epoch 68/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6844 - acc: 0.5647 - val_loss: 0.6824 - val_acc: 0.5800
#
# Epoch 00068: val_acc did not improve from 0.64000
# Epoch 69/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6922 - acc: 0.5223 - val_loss: 0.6820 - val_acc: 0.6400
#
# Epoch 00069: val_acc did not improve from 0.64000
# Epoch 70/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6881 - acc: 0.5670 - val_loss: 0.6813 - val_acc: 0.6400
#
# Epoch 00070: val_acc did not improve from 0.64000
# Epoch 71/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6878 - acc: 0.5312 - val_loss: 0.6806 - val_acc: 0.6600
#
# Epoch 00071: val_acc improved from 0.64000 to 0.66000, saving model to model_21.h5
# Epoch 72/9000
# 448/448 [==============================] - 0s 208us/step - loss: 0.6809 - acc: 0.5647 - val_loss: 0.6797 - val_acc: 0.6400
#
# Epoch 00072: val_acc did not improve from 0.66000
# Epoch 73/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6885 - acc: 0.5089 - val_loss: 0.6791 - val_acc: 0.6400
#
# Epoch 00073: val_acc did not improve from 0.66000
# Epoch 74/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6902 - acc: 0.5134 - val_loss: 0.6783 - val_acc: 0.6400
#
# Epoch 00074: val_acc did not improve from 0.66000
# Epoch 75/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6767 - acc: 0.5558 - val_loss: 0.6771 - val_acc: 0.6200
#
# Epoch 00075: val_acc did not improve from 0.66000
# Epoch 76/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6767 - acc: 0.5915 - val_loss: 0.6756 - val_acc: 0.6200
#
# Epoch 00076: val_acc did not improve from 0.66000
# Epoch 77/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6865 - acc: 0.5290 - val_loss: 0.6747 - val_acc: 0.6200
#
# Epoch 00077: val_acc did not improve from 0.66000
# Epoch 78/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6801 - acc: 0.5781 - val_loss: 0.6741 - val_acc: 0.6200
#
# Epoch 00078: val_acc did not improve from 0.66000
# Epoch 79/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6884 - acc: 0.5179 - val_loss: 0.6742 - val_acc: 0.6200
#
# Epoch 00079: val_acc did not improve from 0.66000
# Epoch 80/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6804 - acc: 0.5469 - val_loss: 0.6728 - val_acc: 0.6200
#
# Epoch 00080: val_acc did not improve from 0.66000
# Epoch 81/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6809 - acc: 0.5558 - val_loss: 0.6711 - val_acc: 0.6200
#
# Epoch 00081: val_acc did not improve from 0.66000
# Epoch 82/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6770 - acc: 0.5491 - val_loss: 0.6701 - val_acc: 0.6200
#
# Epoch 00082: val_acc did not improve from 0.66000
# Epoch 83/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6821 - acc: 0.5536 - val_loss: 0.6697 - val_acc: 0.6400
#
# Epoch 00083: val_acc did not improve from 0.66000
# Epoch 84/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6784 - acc: 0.5647 - val_loss: 0.6685 - val_acc: 0.6200
#
# Epoch 00084: val_acc did not improve from 0.66000
# Epoch 85/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6757 - acc: 0.5692 - val_loss: 0.6657 - val_acc: 0.6200
#
# Epoch 00085: val_acc did not improve from 0.66000
# Epoch 86/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6678 - acc: 0.5536 - val_loss: 0.6636 - val_acc: 0.6200
#
# Epoch 00086: val_acc did not improve from 0.66000
# Epoch 87/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6826 - acc: 0.5491 - val_loss: 0.6631 - val_acc: 0.6400
#
# Epoch 00087: val_acc did not improve from 0.66000
# Epoch 88/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6707 - acc: 0.5804 - val_loss: 0.6619 - val_acc: 0.6400
#
# Epoch 00088: val_acc did not improve from 0.66000
# Epoch 89/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6788 - acc: 0.5536 - val_loss: 0.6606 - val_acc: 0.6400
#
# Epoch 00089: val_acc did not improve from 0.66000
# Epoch 90/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6746 - acc: 0.5513 - val_loss: 0.6574 - val_acc: 0.6200
#
# Epoch 00090: val_acc did not improve from 0.66000
# Epoch 91/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6812 - acc: 0.5781 - val_loss: 0.6545 - val_acc: 0.6400
#
# Epoch 00091: val_acc did not improve from 0.66000
# Epoch 92/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6767 - acc: 0.5871 - val_loss: 0.6536 - val_acc: 0.6200
#
# Epoch 00092: val_acc did not improve from 0.66000
# Epoch 93/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6654 - acc: 0.5871 - val_loss: 0.6503 - val_acc: 0.6800
#
# Epoch 00093: val_acc improved from 0.66000 to 0.68000, saving model to model_21.h5
# Epoch 94/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6781 - acc: 0.5290 - val_loss: 0.6489 - val_acc: 0.6800
#
# Epoch 00094: val_acc did not improve from 0.68000
# Epoch 95/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6776 - acc: 0.5737 - val_loss: 0.6483 - val_acc: 0.6800
#
# Epoch 00095: val_acc did not improve from 0.68000
# Epoch 96/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6713 - acc: 0.5826 - val_loss: 0.6467 - val_acc: 0.6800
#
# Epoch 00096: val_acc did not improve from 0.68000
# Epoch 97/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6725 - acc: 0.5826 - val_loss: 0.6471 - val_acc: 0.6800
#
# Epoch 00097: val_acc did not improve from 0.68000
# Epoch 98/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6673 - acc: 0.5826 - val_loss: 0.6455 - val_acc: 0.6800
#
# Epoch 00098: val_acc did not improve from 0.68000
# Epoch 99/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6625 - acc: 0.6004 - val_loss: 0.6435 - val_acc: 0.6800
#
# Epoch 00099: val_acc did not improve from 0.68000
# Epoch 100/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6578 - acc: 0.6138 - val_loss: 0.6410 - val_acc: 0.6800
#
# Epoch 00100: val_acc did not improve from 0.68000
# Epoch 101/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6626 - acc: 0.5915 - val_loss: 0.6396 - val_acc: 0.6800
#
# Epoch 00101: val_acc did not improve from 0.68000
# Epoch 102/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6476 - acc: 0.6250 - val_loss: 0.6365 - val_acc: 0.6800
#
# Epoch 00102: val_acc did not improve from 0.68000
# Epoch 103/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6581 - acc: 0.6272 - val_loss: 0.6363 - val_acc: 0.6800
#
# Epoch 00103: val_acc did not improve from 0.68000
# Epoch 104/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6559 - acc: 0.6339 - val_loss: 0.6338 - val_acc: 0.6800
#
# Epoch 00104: val_acc did not improve from 0.68000
# Epoch 105/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6591 - acc: 0.6228 - val_loss: 0.6304 - val_acc: 0.6800
#
# Epoch 00105: val_acc did not improve from 0.68000
# Epoch 106/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6488 - acc: 0.6004 - val_loss: 0.6297 - val_acc: 0.6800
#
# Epoch 00106: val_acc did not improve from 0.68000
# Epoch 107/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6630 - acc: 0.6027 - val_loss: 0.6295 - val_acc: 0.6800
#
# Epoch 00107: val_acc did not improve from 0.68000
# Epoch 108/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6646 - acc: 0.5692 - val_loss: 0.6277 - val_acc: 0.6800
#
# Epoch 00108: val_acc did not improve from 0.68000
# Epoch 109/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6432 - acc: 0.6384 - val_loss: 0.6265 - val_acc: 0.6800
#
# Epoch 00109: val_acc did not improve from 0.68000
# Epoch 110/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6571 - acc: 0.6384 - val_loss: 0.6267 - val_acc: 0.6800
#
# Epoch 00110: val_acc did not improve from 0.68000
# Epoch 111/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6606 - acc: 0.6071 - val_loss: 0.6264 - val_acc: 0.6800
#
# Epoch 00111: val_acc did not improve from 0.68000
# Epoch 112/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6731 - acc: 0.5625 - val_loss: 0.6275 - val_acc: 0.6800
#
# Epoch 00112: val_acc did not improve from 0.68000
# Epoch 113/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.6529 - acc: 0.6094 - val_loss: 0.6271 - val_acc: 0.6800
#
# Epoch 00113: val_acc did not improve from 0.68000
# Epoch 114/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6808 - acc: 0.5625 - val_loss: 0.6272 - val_acc: 0.6800
#
# Epoch 00114: val_acc did not improve from 0.68000
# Epoch 115/9000
# 448/448 [==============================] - 0s 223us/step - loss: 0.6527 - acc: 0.6071 - val_loss: 0.6272 - val_acc: 0.6800
#
# Epoch 00115: val_acc did not improve from 0.68000
# Epoch 116/9000
# 448/448 [==============================] - 0s 211us/step - loss: 0.6674 - acc: 0.6027 - val_loss: 0.6276 - val_acc: 0.6800
#
# Epoch 00116: val_acc did not improve from 0.68000
# Epoch 117/9000
# 448/448 [==============================] - 0s 224us/step - loss: 0.6406 - acc: 0.6674 - val_loss: 0.6255 - val_acc: 0.6800
#
# Epoch 00117: val_acc did not improve from 0.68000
# Epoch 118/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.6524 - acc: 0.6272 - val_loss: 0.6227 - val_acc: 0.7000
#
# Epoch 00118: val_acc improved from 0.68000 to 0.70000, saving model to model_21.h5
# Epoch 119/9000
# 448/448 [==============================] - 0s 211us/step - loss: 0.6683 - acc: 0.6027 - val_loss: 0.6232 - val_acc: 0.7000
#
# Epoch 00119: val_acc did not improve from 0.70000
# Epoch 120/9000
# 448/448 [==============================] - 0s 209us/step - loss: 0.6576 - acc: 0.6250 - val_loss: 0.6241 - val_acc: 0.7000
#
# Epoch 00120: val_acc did not improve from 0.70000
# Epoch 121/9000
# 448/448 [==============================] - 0s 222us/step - loss: 0.6466 - acc: 0.6562 - val_loss: 0.6233 - val_acc: 0.7000
#
# Epoch 00121: val_acc did not improve from 0.70000
# Epoch 122/9000
# 448/448 [==============================] - 0s 204us/step - loss: 0.6528 - acc: 0.6004 - val_loss: 0.6207 - val_acc: 0.7000
#
# Epoch 00122: val_acc did not improve from 0.70000
# Epoch 123/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.6445 - acc: 0.6406 - val_loss: 0.6183 - val_acc: 0.7200
#
# Epoch 00123: val_acc improved from 0.70000 to 0.72000, saving model to model_21.h5
# Epoch 124/9000
# 448/448 [==============================] - 0s 201us/step - loss: 0.6607 - acc: 0.6027 - val_loss: 0.6192 - val_acc: 0.7200
#
# Epoch 00124: val_acc did not improve from 0.72000
# Epoch 125/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.6418 - acc: 0.6451 - val_loss: 0.6171 - val_acc: 0.7200
#
# Epoch 00125: val_acc did not improve from 0.72000
# Epoch 126/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6335 - acc: 0.6250 - val_loss: 0.6150 - val_acc: 0.7800
#
# Epoch 00126: val_acc improved from 0.72000 to 0.78000, saving model to model_21.h5
# Epoch 127/9000
# 448/448 [==============================] - 0s 204us/step - loss: 0.6473 - acc: 0.6429 - val_loss: 0.6159 - val_acc: 0.7200
#
# Epoch 00127: val_acc did not improve from 0.78000
# Epoch 128/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6604 - acc: 0.6183 - val_loss: 0.6153 - val_acc: 0.7000
#
# Epoch 00128: val_acc did not improve from 0.78000
# Epoch 129/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6572 - acc: 0.6228 - val_loss: 0.6166 - val_acc: 0.7000
#
# Epoch 00129: val_acc did not improve from 0.78000
# Epoch 130/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6548 - acc: 0.6116 - val_loss: 0.6168 - val_acc: 0.7000
#
# Epoch 00130: val_acc did not improve from 0.78000
# Epoch 131/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6566 - acc: 0.6116 - val_loss: 0.6162 - val_acc: 0.7000
#
# Epoch 00131: val_acc did not improve from 0.78000
# Epoch 132/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6510 - acc: 0.6295 - val_loss: 0.6160 - val_acc: 0.7200
#
# Epoch 00132: val_acc did not improve from 0.78000
# Epoch 133/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6544 - acc: 0.6317 - val_loss: 0.6155 - val_acc: 0.7200
#
# Epoch 00133: val_acc did not improve from 0.78000
# Epoch 134/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6579 - acc: 0.6317 - val_loss: 0.6163 - val_acc: 0.7800
#
# Epoch 00134: val_acc did not improve from 0.78000
# Epoch 135/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6454 - acc: 0.6250 - val_loss: 0.6153 - val_acc: 0.7800
#
# Epoch 00135: val_acc did not improve from 0.78000
# Epoch 136/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6500 - acc: 0.6339 - val_loss: 0.6134 - val_acc: 0.7800
#
# Epoch 00136: val_acc did not improve from 0.78000
# Epoch 137/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6599 - acc: 0.6116 - val_loss: 0.6148 - val_acc: 0.7800
#
# Epoch 00137: val_acc did not improve from 0.78000
# Epoch 138/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6549 - acc: 0.5982 - val_loss: 0.6157 - val_acc: 0.7400
#
# Epoch 00138: val_acc did not improve from 0.78000
# Epoch 139/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6528 - acc: 0.6161 - val_loss: 0.6149 - val_acc: 0.7600
#
# Epoch 00139: val_acc did not improve from 0.78000
# Epoch 140/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6303 - acc: 0.6607 - val_loss: 0.6152 - val_acc: 0.7000
#
# Epoch 00140: val_acc did not improve from 0.78000
# Epoch 141/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6440 - acc: 0.6228 - val_loss: 0.6135 - val_acc: 0.7200
#
# Epoch 00141: val_acc did not improve from 0.78000
# Epoch 142/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6263 - acc: 0.6562 - val_loss: 0.6117 - val_acc: 0.7200
#
# Epoch 00142: val_acc did not improve from 0.78000
# Epoch 143/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6471 - acc: 0.6518 - val_loss: 0.6120 - val_acc: 0.7200
#
# Epoch 00143: val_acc did not improve from 0.78000
# Epoch 144/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6374 - acc: 0.6562 - val_loss: 0.6109 - val_acc: 0.7000
#
# Epoch 00144: val_acc did not improve from 0.78000
# Epoch 145/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6398 - acc: 0.6094 - val_loss: 0.6102 - val_acc: 0.7000
#
# Epoch 00145: val_acc did not improve from 0.78000
# Epoch 146/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6356 - acc: 0.6562 - val_loss: 0.6109 - val_acc: 0.7000
#
# Epoch 00146: val_acc did not improve from 0.78000
# Epoch 147/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6412 - acc: 0.6585 - val_loss: 0.6100 - val_acc: 0.7000
#
# Epoch 00147: val_acc did not improve from 0.78000
# Epoch 148/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6466 - acc: 0.6205 - val_loss: 0.6119 - val_acc: 0.7000
#
# Epoch 00148: val_acc did not improve from 0.78000
# Epoch 149/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6526 - acc: 0.6496 - val_loss: 0.6115 - val_acc: 0.7200
#
# Epoch 00149: val_acc did not improve from 0.78000
# Epoch 150/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6314 - acc: 0.6451 - val_loss: 0.6109 - val_acc: 0.7200
#
# Epoch 00150: val_acc did not improve from 0.78000
# Epoch 151/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6366 - acc: 0.6205 - val_loss: 0.6110 - val_acc: 0.7200
#
# Epoch 00151: val_acc did not improve from 0.78000
# Epoch 152/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6511 - acc: 0.6317 - val_loss: 0.6104 - val_acc: 0.7200
#
# Epoch 00152: val_acc did not improve from 0.78000
# Epoch 153/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6368 - acc: 0.6607 - val_loss: 0.6106 - val_acc: 0.7000
#
# Epoch 00153: val_acc did not improve from 0.78000
# Epoch 154/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6354 - acc: 0.6183 - val_loss: 0.6094 - val_acc: 0.7000
#
# Epoch 00154: val_acc did not improve from 0.78000
# Epoch 155/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6412 - acc: 0.6272 - val_loss: 0.6099 - val_acc: 0.7000
#
# Epoch 00155: val_acc did not improve from 0.78000
# Epoch 156/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6426 - acc: 0.6429 - val_loss: 0.6088 - val_acc: 0.7200
#
# Epoch 00156: val_acc did not improve from 0.78000
# Epoch 157/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6509 - acc: 0.6250 - val_loss: 0.6086 - val_acc: 0.7000
#
# Epoch 00157: val_acc did not improve from 0.78000
# Epoch 158/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6288 - acc: 0.6183 - val_loss: 0.6085 - val_acc: 0.7000
#
# Epoch 00158: val_acc did not improve from 0.78000
# Epoch 159/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6322 - acc: 0.6429 - val_loss: 0.6079 - val_acc: 0.7000
#
# Epoch 00159: val_acc did not improve from 0.78000
# Epoch 160/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6572 - acc: 0.6161 - val_loss: 0.6080 - val_acc: 0.7000
#
# Epoch 00160: val_acc did not improve from 0.78000
# Epoch 161/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6521 - acc: 0.6473 - val_loss: 0.6082 - val_acc: 0.7200
#
# Epoch 00161: val_acc did not improve from 0.78000
# Epoch 162/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6411 - acc: 0.6384 - val_loss: 0.6086 - val_acc: 0.7400
#
# Epoch 00162: val_acc did not improve from 0.78000
# Epoch 163/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6400 - acc: 0.6272 - val_loss: 0.6095 - val_acc: 0.7200
#
# Epoch 00163: val_acc did not improve from 0.78000
# Epoch 164/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6300 - acc: 0.6406 - val_loss: 0.6088 - val_acc: 0.7200
#
# Epoch 00164: val_acc did not improve from 0.78000
# Epoch 165/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6373 - acc: 0.6473 - val_loss: 0.6083 - val_acc: 0.7000
#
# Epoch 00165: val_acc did not improve from 0.78000
# Epoch 166/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6330 - acc: 0.6830 - val_loss: 0.6078 - val_acc: 0.7400
#
# Epoch 00166: val_acc did not improve from 0.78000
# Epoch 167/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6510 - acc: 0.6183 - val_loss: 0.6078 - val_acc: 0.7800
#
# Epoch 00167: val_acc did not improve from 0.78000
# Epoch 168/9000
# 448/448 [==============================] - 0s 217us/step - loss: 0.6218 - acc: 0.6629 - val_loss: 0.6086 - val_acc: 0.7200
#
# Epoch 00168: val_acc did not improve from 0.78000
# Epoch 169/9000
# 448/448 [==============================] - 0s 208us/step - loss: 0.6399 - acc: 0.6339 - val_loss: 0.6089 - val_acc: 0.7200
#
# Epoch 00169: val_acc did not improve from 0.78000
# Epoch 170/9000
# 448/448 [==============================] - 0s 225us/step - loss: 0.6299 - acc: 0.6384 - val_loss: 0.6085 - val_acc: 0.7000
#
# Epoch 00170: val_acc did not improve from 0.78000
# Epoch 171/9000
# 448/448 [==============================] - 0s 209us/step - loss: 0.6393 - acc: 0.6339 - val_loss: 0.6071 - val_acc: 0.7200
#
# Epoch 00171: val_acc did not improve from 0.78000
# Epoch 172/9000
# 448/448 [==============================] - 0s 206us/step - loss: 0.6462 - acc: 0.6473 - val_loss: 0.6070 - val_acc: 0.7000
#
# Epoch 00172: val_acc did not improve from 0.78000
# Epoch 173/9000
# 448/448 [==============================] - 0s 213us/step - loss: 0.6378 - acc: 0.6429 - val_loss: 0.6081 - val_acc: 0.7400
#
# Epoch 00173: val_acc did not improve from 0.78000
# Epoch 174/9000
# 448/448 [==============================] - 0s 217us/step - loss: 0.6484 - acc: 0.6138 - val_loss: 0.6079 - val_acc: 0.7000
#
# Epoch 00174: val_acc did not improve from 0.78000
# Epoch 175/9000
# 448/448 [==============================] - 0s 212us/step - loss: 0.6392 - acc: 0.6317 - val_loss: 0.6075 - val_acc: 0.7000
#
# Epoch 00175: val_acc did not improve from 0.78000
# Epoch 176/9000
# 448/448 [==============================] - 0s 204us/step - loss: 0.6463 - acc: 0.6696 - val_loss: 0.6072 - val_acc: 0.7200
#
# Epoch 00176: val_acc did not improve from 0.78000
# Epoch 177/9000
# 448/448 [==============================] - 0s 202us/step - loss: 0.6345 - acc: 0.6339 - val_loss: 0.6070 - val_acc: 0.7000
#
# Epoch 00177: val_acc did not improve from 0.78000
# Epoch 178/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6304 - acc: 0.6652 - val_loss: 0.6067 - val_acc: 0.7400
#
# Epoch 00178: val_acc did not improve from 0.78000
# Epoch 179/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6339 - acc: 0.6362 - val_loss: 0.6062 - val_acc: 0.7400
#
# Epoch 00179: val_acc did not improve from 0.78000
# Epoch 180/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6448 - acc: 0.6451 - val_loss: 0.6069 - val_acc: 0.7200
#
# Epoch 00180: val_acc did not improve from 0.78000
# Epoch 181/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6435 - acc: 0.6228 - val_loss: 0.6066 - val_acc: 0.7000
#
# Epoch 00181: val_acc did not improve from 0.78000
# Epoch 182/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6365 - acc: 0.6362 - val_loss: 0.6061 - val_acc: 0.7000
#
# Epoch 00182: val_acc did not improve from 0.78000
# Epoch 183/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6381 - acc: 0.6339 - val_loss: 0.6057 - val_acc: 0.7000
#
# Epoch 00183: val_acc did not improve from 0.78000
# Epoch 184/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6332 - acc: 0.6496 - val_loss: 0.6049 - val_acc: 0.7200
#
# Epoch 00184: val_acc did not improve from 0.78000
# Epoch 185/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6283 - acc: 0.6473 - val_loss: 0.6040 - val_acc: 0.7000
#
# Epoch 00185: val_acc did not improve from 0.78000
# Epoch 186/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6297 - acc: 0.6272 - val_loss: 0.6030 - val_acc: 0.7000
#
# Epoch 00186: val_acc did not improve from 0.78000
# Epoch 187/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6242 - acc: 0.6741 - val_loss: 0.6023 - val_acc: 0.7200
#
# Epoch 00187: val_acc did not improve from 0.78000
# Epoch 188/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6397 - acc: 0.6339 - val_loss: 0.6037 - val_acc: 0.7200
#
# Epoch 00188: val_acc did not improve from 0.78000
# Epoch 189/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6373 - acc: 0.6250 - val_loss: 0.6041 - val_acc: 0.7200
#
# Epoch 00189: val_acc did not improve from 0.78000
# Epoch 190/9000
# 448/448 [==============================] - 0s 225us/step - loss: 0.6350 - acc: 0.6250 - val_loss: 0.6037 - val_acc: 0.7600
#
# Epoch 00190: val_acc did not improve from 0.78000
# Epoch 191/9000
# 448/448 [==============================] - 0s 210us/step - loss: 0.6437 - acc: 0.6540 - val_loss: 0.6029 - val_acc: 0.7600
#
# Epoch 00191: val_acc did not improve from 0.78000
# Epoch 192/9000
# 448/448 [==============================] - 0s 226us/step - loss: 0.6364 - acc: 0.6496 - val_loss: 0.6044 - val_acc: 0.7800
#
# Epoch 00192: val_acc did not improve from 0.78000
# Epoch 193/9000
# 448/448 [==============================] - 0s 209us/step - loss: 0.6416 - acc: 0.6473 - val_loss: 0.6048 - val_acc: 0.7600
#
# Epoch 00193: val_acc did not improve from 0.78000
# Epoch 194/9000
# 448/448 [==============================] - 0s 209us/step - loss: 0.6263 - acc: 0.6518 - val_loss: 0.6043 - val_acc: 0.7800
#
# Epoch 00194: val_acc did not improve from 0.78000
# Epoch 195/9000
# 448/448 [==============================] - 0s 209us/step - loss: 0.6300 - acc: 0.6272 - val_loss: 0.6044 - val_acc: 0.7800
#
# Epoch 00195: val_acc did not improve from 0.78000
# Epoch 196/9000
# 448/448 [==============================] - 0s 221us/step - loss: 0.6383 - acc: 0.6406 - val_loss: 0.6042 - val_acc: 0.7800
#
# Epoch 00196: val_acc did not improve from 0.78000
# Epoch 197/9000
# 448/448 [==============================] - 0s 212us/step - loss: 0.6262 - acc: 0.6652 - val_loss: 0.6037 - val_acc: 0.7800
#
# Epoch 00197: val_acc did not improve from 0.78000
# Epoch 198/9000
# 448/448 [==============================] - 0s 206us/step - loss: 0.6147 - acc: 0.6585 - val_loss: 0.6033 - val_acc: 0.7800
#
# Epoch 00198: val_acc did not improve from 0.78000
# Epoch 199/9000
# 448/448 [==============================] - 0s 203us/step - loss: 0.6314 - acc: 0.6451 - val_loss: 0.6034 - val_acc: 0.7800
#
# Epoch 00199: val_acc did not improve from 0.78000
# Epoch 200/9000
# 448/448 [==============================] - 0s 201us/step - loss: 0.6513 - acc: 0.6317 - val_loss: 0.6044 - val_acc: 0.7800
#
# Epoch 00200: val_acc did not improve from 0.78000
# Epoch 201/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6236 - acc: 0.6496 - val_loss: 0.6041 - val_acc: 0.7800
#
# Epoch 00201: val_acc did not improve from 0.78000
# Epoch 202/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.6243 - acc: 0.6652 - val_loss: 0.6035 - val_acc: 0.7800
#
# Epoch 00202: val_acc did not improve from 0.78000
# Epoch 203/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6475 - acc: 0.6384 - val_loss: 0.6039 - val_acc: 0.7800
#
# Epoch 00203: val_acc did not improve from 0.78000
# Epoch 204/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6381 - acc: 0.6317 - val_loss: 0.6039 - val_acc: 0.7800
#
# Epoch 00204: val_acc did not improve from 0.78000
# Epoch 205/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6379 - acc: 0.6607 - val_loss: 0.6040 - val_acc: 0.7800
#
# Epoch 00205: val_acc did not improve from 0.78000
# Epoch 206/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6463 - acc: 0.6183 - val_loss: 0.6037 - val_acc: 0.7800
#
# Epoch 00206: val_acc did not improve from 0.78000
# Epoch 207/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6456 - acc: 0.6473 - val_loss: 0.6051 - val_acc: 0.7800
#
# Epoch 00207: val_acc did not improve from 0.78000
# Epoch 208/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6416 - acc: 0.6228 - val_loss: 0.6057 - val_acc: 0.7800
#
# Epoch 00208: val_acc did not improve from 0.78000
# Epoch 209/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6375 - acc: 0.6205 - val_loss: 0.6069 - val_acc: 0.7800
#
# Epoch 00209: val_acc did not improve from 0.78000
# Epoch 210/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6262 - acc: 0.6674 - val_loss: 0.6058 - val_acc: 0.7800
#
# Epoch 00210: val_acc did not improve from 0.78000
# Epoch 211/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6369 - acc: 0.6362 - val_loss: 0.6052 - val_acc: 0.7800
#
# Epoch 00211: val_acc did not improve from 0.78000
# Epoch 212/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6343 - acc: 0.6562 - val_loss: 0.6066 - val_acc: 0.7600
#
# Epoch 00212: val_acc did not improve from 0.78000
# Epoch 213/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6225 - acc: 0.6629 - val_loss: 0.6053 - val_acc: 0.7800
#
# Epoch 00213: val_acc did not improve from 0.78000
# Epoch 214/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6219 - acc: 0.6473 - val_loss: 0.6047 - val_acc: 0.7800
#
# Epoch 00214: val_acc did not improve from 0.78000
# Epoch 215/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6157 - acc: 0.6696 - val_loss: 0.6039 - val_acc: 0.7800
#
# Epoch 00215: val_acc did not improve from 0.78000
# Epoch 216/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6325 - acc: 0.6629 - val_loss: 0.6033 - val_acc: 0.7800
#
# Epoch 00216: val_acc did not improve from 0.78000
# Epoch 217/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6402 - acc: 0.6094 - val_loss: 0.6038 - val_acc: 0.7800
#
# Epoch 00217: val_acc did not improve from 0.78000
# Epoch 218/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6258 - acc: 0.6473 - val_loss: 0.6039 - val_acc: 0.7800
#
# Epoch 00218: val_acc did not improve from 0.78000
# Epoch 219/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6238 - acc: 0.6339 - val_loss: 0.6038 - val_acc: 0.7800
#
# Epoch 00219: val_acc did not improve from 0.78000
# Epoch 220/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6269 - acc: 0.6250 - val_loss: 0.6024 - val_acc: 0.7800
#
# Epoch 00220: val_acc did not improve from 0.78000
# Epoch 221/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6208 - acc: 0.6451 - val_loss: 0.6016 - val_acc: 0.7800
#
# Epoch 00221: val_acc did not improve from 0.78000
# Epoch 222/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.6259 - acc: 0.6496 - val_loss: 0.5999 - val_acc: 0.7800
#
# Epoch 00222: val_acc did not improve from 0.78000
# Epoch 223/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6394 - acc: 0.6652 - val_loss: 0.6001 - val_acc: 0.7800
#
# Epoch 00223: val_acc did not improve from 0.78000
# Epoch 224/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6437 - acc: 0.6295 - val_loss: 0.6016 - val_acc: 0.7800
#
# Epoch 00224: val_acc did not improve from 0.78000
# Epoch 225/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6403 - acc: 0.6496 - val_loss: 0.6028 - val_acc: 0.7800
#
# Epoch 00225: val_acc did not improve from 0.78000
# Epoch 226/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6276 - acc: 0.6562 - val_loss: 0.6027 - val_acc: 0.7800
#
# Epoch 00226: val_acc did not improve from 0.78000
# Epoch 227/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6359 - acc: 0.6272 - val_loss: 0.6037 - val_acc: 0.7600
#
# Epoch 00227: val_acc did not improve from 0.78000
# Epoch 228/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6329 - acc: 0.6473 - val_loss: 0.6024 - val_acc: 0.7600
#
# Epoch 00228: val_acc did not improve from 0.78000
# Epoch 229/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6226 - acc: 0.6741 - val_loss: 0.6021 - val_acc: 0.7600
#
# Epoch 00229: val_acc did not improve from 0.78000
# Epoch 230/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6254 - acc: 0.6562 - val_loss: 0.5998 - val_acc: 0.7600
#
# Epoch 00230: val_acc did not improve from 0.78000
# Epoch 231/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6319 - acc: 0.6496 - val_loss: 0.6008 - val_acc: 0.7600
#
# Epoch 00231: val_acc did not improve from 0.78000
# Epoch 232/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6179 - acc: 0.6473 - val_loss: 0.5994 - val_acc: 0.7600
#
# Epoch 00232: val_acc did not improve from 0.78000
# Epoch 233/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6238 - acc: 0.6562 - val_loss: 0.5997 - val_acc: 0.7400
#
# Epoch 00233: val_acc did not improve from 0.78000
# Epoch 234/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6178 - acc: 0.6830 - val_loss: 0.5987 - val_acc: 0.7400
#
# Epoch 00234: val_acc did not improve from 0.78000
# Epoch 235/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6052 - acc: 0.6830 - val_loss: 0.5963 - val_acc: 0.7400
#
# Epoch 00235: val_acc did not improve from 0.78000
# Epoch 236/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6163 - acc: 0.6674 - val_loss: 0.5955 - val_acc: 0.7400
#
# Epoch 00236: val_acc did not improve from 0.78000
# Epoch 237/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6340 - acc: 0.6451 - val_loss: 0.5951 - val_acc: 0.7600
#
# Epoch 00237: val_acc did not improve from 0.78000
# Epoch 238/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6352 - acc: 0.6362 - val_loss: 0.5966 - val_acc: 0.7600
#
# Epoch 00238: val_acc did not improve from 0.78000
# Epoch 239/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6280 - acc: 0.6473 - val_loss: 0.5958 - val_acc: 0.7600
#
# Epoch 00239: val_acc did not improve from 0.78000
# Epoch 240/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6191 - acc: 0.6562 - val_loss: 0.5965 - val_acc: 0.7600
#
# Epoch 00240: val_acc did not improve from 0.78000
# Epoch 241/9000
# 448/448 [==============================] - 0s 199us/step - loss: 0.6149 - acc: 0.6540 - val_loss: 0.5958 - val_acc: 0.7400
#
# Epoch 00241: val_acc did not improve from 0.78000
# Epoch 242/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6048 - acc: 0.6987 - val_loss: 0.5940 - val_acc: 0.7400
#
# Epoch 00242: val_acc did not improve from 0.78000
# Epoch 243/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.6122 - acc: 0.6161 - val_loss: 0.5947 - val_acc: 0.7400
#
# Epoch 00243: val_acc did not improve from 0.78000
# Epoch 244/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6392 - acc: 0.6518 - val_loss: 0.5948 - val_acc: 0.7400
#
# Epoch 00244: val_acc did not improve from 0.78000
# Epoch 245/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6324 - acc: 0.6607 - val_loss: 0.5957 - val_acc: 0.7400
#
# Epoch 00245: val_acc did not improve from 0.78000
# Epoch 246/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6397 - acc: 0.6384 - val_loss: 0.5972 - val_acc: 0.7400
#
# Epoch 00246: val_acc did not improve from 0.78000
# Epoch 247/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6176 - acc: 0.6652 - val_loss: 0.5966 - val_acc: 0.7400
#
# Epoch 00247: val_acc did not improve from 0.78000
# Epoch 248/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6326 - acc: 0.6562 - val_loss: 0.5970 - val_acc: 0.7400
#
# Epoch 00248: val_acc did not improve from 0.78000
# Epoch 249/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.6217 - acc: 0.6451 - val_loss: 0.5973 - val_acc: 0.7400
#
# Epoch 00249: val_acc did not improve from 0.78000
# Epoch 250/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.6199 - acc: 0.6540 - val_loss: 0.5972 - val_acc: 0.7400
#
# Epoch 00250: val_acc did not improve from 0.78000
# Epoch 251/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6202 - acc: 0.6652 - val_loss: 0.5966 - val_acc: 0.7600
#
# Epoch 00251: val_acc did not improve from 0.78000
# Epoch 252/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6110 - acc: 0.6674 - val_loss: 0.5954 - val_acc: 0.7400
#
# Epoch 00252: val_acc did not improve from 0.78000
# Epoch 253/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.6413 - acc: 0.6429 - val_loss: 0.5982 - val_acc: 0.7400
#
# ...
#
# Epoch 06926: val_acc did not improve from 0.88000
# Epoch 6927/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0866 - acc: 0.9710 - val_loss: 0.6861 - val_acc: 0.7800
#
# Epoch 06927: val_acc did not improve from 0.88000
# Epoch 6928/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.0798 - acc: 0.9710 - val_loss: 0.6971 - val_acc: 0.7600
#
# Epoch 06928: val_acc did not improve from 0.88000
# Epoch 6929/9000
# 448/448 [==============================] - 0s 194us/step - loss: 0.0975 - acc: 0.9665 - val_loss: 0.7092 - val_acc: 0.7400
#
# Epoch 06929: val_acc did not improve from 0.88000
# Epoch 6930/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1298 - acc: 0.9621 - val_loss: 0.7126 - val_acc: 0.7200
#
# Epoch 06930: val_acc did not improve from 0.88000
# Epoch 6931/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.1379 - acc: 0.9442 - val_loss: 0.7128 - val_acc: 0.7200
#
# Epoch 06931: val_acc did not improve from 0.88000
# Epoch 6932/9000
# 448/448 [==============================] - 0s 198us/step - loss: 0.0942 - acc: 0.9665 - val_loss: 0.7018 - val_acc: 0.7400
#
# Epoch 06932: val_acc did not improve from 0.88000
# Epoch 6933/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1279 - acc: 0.9554 - val_loss: 0.6959 - val_acc: 0.7400
#
# Epoch 06933: val_acc did not improve from 0.88000
# Epoch 6934/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1163 - acc: 0.9531 - val_loss: 0.6975 - val_acc: 0.7400
#
# Epoch 06934: val_acc did not improve from 0.88000
# Epoch 6935/9000
# 448/448 [==============================] - 0s 201us/step - loss: 0.0941 - acc: 0.9621 - val_loss: 0.6908 - val_acc: 0.7400
#
# Epoch 06935: val_acc did not improve from 0.88000
# Epoch 6936/9000
# 448/448 [==============================] - 0s 208us/step - loss: 0.1040 - acc: 0.9621 - val_loss: 0.6869 - val_acc: 0.7600
#
# Epoch 06936: val_acc did not improve from 0.88000
# Epoch 6937/9000
# 448/448 [==============================] - 0s 214us/step - loss: 0.1295 - acc: 0.9621 - val_loss: 0.6851 - val_acc: 0.7600
#
# Epoch 06937: val_acc did not improve from 0.88000
# Epoch 6938/9000
# 448/448 [==============================] - 0s 207us/step - loss: 0.1249 - acc: 0.9576 - val_loss: 0.6926 - val_acc: 0.7400
#
# Epoch 06938: val_acc did not improve from 0.88000
# Epoch 6939/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.1151 - acc: 0.9576 - val_loss: 0.6925 - val_acc: 0.7200
#
# Epoch 06939: val_acc did not improve from 0.88000
# Epoch 6940/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.1394 - acc: 0.9509 - val_loss: 0.6908 - val_acc: 0.7400
#
# Epoch 06940: val_acc did not improve from 0.88000
# Epoch 6941/9000
# 448/448 [==============================] - 0s 210us/step - loss: 0.0802 - acc: 0.9688 - val_loss: 0.6808 - val_acc: 0.7400
#
# Epoch 06941: val_acc did not improve from 0.88000
# Epoch 6942/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.0818 - acc: 0.9754 - val_loss: 0.6816 - val_acc: 0.7400
#
# Epoch 06942: val_acc did not improve from 0.88000
# Epoch 6943/9000
# 448/448 [==============================] - 0s 205us/step - loss: 0.1114 - acc: 0.9688 - val_loss: 0.6727 - val_acc: 0.7600
#
# Epoch 06943: val_acc did not improve from 0.88000
# Epoch 6944/9000
# 448/448 [==============================] - 0s 201us/step - loss: 0.1140 - acc: 0.9554 - val_loss: 0.6726 - val_acc: 0.7400
#
# Epoch 06944: val_acc did not improve from 0.88000
# Epoch 6945/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1117 - acc: 0.9487 - val_loss: 0.6767 - val_acc: 0.7400
#
# Epoch 06945: val_acc did not improve from 0.88000
# Epoch 6946/9000
# 448/448 [==============================] - 0s 201us/step - loss: 0.1515 - acc: 0.9576 - val_loss: 0.6716 - val_acc: 0.7600
#
# Epoch 06946: val_acc did not improve from 0.88000
# Epoch 6947/9000
# 448/448 [==============================] - 0s 200us/step - loss: 0.0955 - acc: 0.9710 - val_loss: 0.6763 - val_acc: 0.7800
#
# Epoch 06947: val_acc did not improve from 0.88000
# Epoch 6948/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1247 - acc: 0.9509 - val_loss: 0.6788 - val_acc: 0.7600
#
# Epoch 06948: val_acc did not improve from 0.88000
# Epoch 6949/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.0801 - acc: 0.9643 - val_loss: 0.6867 - val_acc: 0.7600
#
# Epoch 06949: val_acc did not improve from 0.88000
# Epoch 6950/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.1397 - acc: 0.9375 - val_loss: 0.6895 - val_acc: 0.7200
#
# Epoch 06950: val_acc did not improve from 0.88000
# Epoch 6951/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1133 - acc: 0.9487 - val_loss: 0.6822 - val_acc: 0.7400
#
# Epoch 06951: val_acc did not improve from 0.88000
# Epoch 6952/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1083 - acc: 0.9554 - val_loss: 0.6896 - val_acc: 0.7200
#
# Epoch 06952: val_acc did not improve from 0.88000
# Epoch 6953/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0710 - acc: 0.9688 - val_loss: 0.6955 - val_acc: 0.7200
#
# Epoch 06953: val_acc did not improve from 0.88000
# Epoch 6954/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1306 - acc: 0.9531 - val_loss: 0.7133 - val_acc: 0.7200
#
# Epoch 06954: val_acc did not improve from 0.88000
# Epoch 6955/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1122 - acc: 0.9598 - val_loss: 0.6869 - val_acc: 0.7400
#
# Epoch 06955: val_acc did not improve from 0.88000
# Epoch 6956/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1203 - acc: 0.9621 - val_loss: 0.6851 - val_acc: 0.7400
#
# Epoch 06956: val_acc did not improve from 0.88000
# Epoch 6957/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1258 - acc: 0.9621 - val_loss: 0.6925 - val_acc: 0.7000
#
# Epoch 06957: val_acc did not improve from 0.88000
# Epoch 6958/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1087 - acc: 0.9531 - val_loss: 0.6983 - val_acc: 0.7000
#
# Epoch 06958: val_acc did not improve from 0.88000
# Epoch 6959/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.0960 - acc: 0.9665 - val_loss: 0.6902 - val_acc: 0.7400
#
# Epoch 06959: val_acc did not improve from 0.88000
# Epoch 6960/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1181 - acc: 0.9665 - val_loss: 0.6825 - val_acc: 0.7400
#
# Epoch 06960: val_acc did not improve from 0.88000
# Epoch 6961/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1247 - acc: 0.9554 - val_loss: 0.6769 - val_acc: 0.7600
#
# Epoch 06961: val_acc did not improve from 0.88000
# Epoch 6962/9000
# 448/448 [==============================] - 0s 194us/step - loss: 0.0987 - acc: 0.9710 - val_loss: 0.6663 - val_acc: 0.7600
#
# Epoch 06962: val_acc did not improve from 0.88000
# Epoch 6963/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1100 - acc: 0.9598 - val_loss: 0.6617 - val_acc: 0.7600
#
# Epoch 06963: val_acc did not improve from 0.88000
# Epoch 6964/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0953 - acc: 0.9643 - val_loss: 0.6618 - val_acc: 0.7600
#
# Epoch 06964: val_acc did not improve from 0.88000
# Epoch 6965/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0790 - acc: 0.9688 - val_loss: 0.6658 - val_acc: 0.7600
#
# Epoch 06965: val_acc did not improve from 0.88000
# Epoch 6966/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1212 - acc: 0.9576 - val_loss: 0.6747 - val_acc: 0.7600
#
# Epoch 06966: val_acc did not improve from 0.88000
# Epoch 6967/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0975 - acc: 0.9643 - val_loss: 0.6819 - val_acc: 0.7600
#
# Epoch 06967: val_acc did not improve from 0.88000
# Epoch 6968/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1340 - acc: 0.9464 - val_loss: 0.6788 - val_acc: 0.7600
#
# Epoch 06968: val_acc did not improve from 0.88000
# Epoch 6969/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.0993 - acc: 0.9688 - val_loss: 0.6816 - val_acc: 0.7600
#
# Epoch 06969: val_acc did not improve from 0.88000
# Epoch 6970/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1083 - acc: 0.9576 - val_loss: 0.6847 - val_acc: 0.7600
#
# Epoch 06970: val_acc did not improve from 0.88000
# Epoch 6971/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1174 - acc: 0.9554 - val_loss: 0.6786 - val_acc: 0.7600
#
# Epoch 06971: val_acc did not improve from 0.88000
# Epoch 6972/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1052 - acc: 0.9643 - val_loss: 0.6816 - val_acc: 0.7600
#
# Epoch 06972: val_acc did not improve from 0.88000
# Epoch 6973/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.0762 - acc: 0.9665 - val_loss: 0.6808 - val_acc: 0.7600
#
# Epoch 06973: val_acc did not improve from 0.88000
# Epoch 6974/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.1294 - acc: 0.9487 - val_loss: 0.6801 - val_acc: 0.7400
#
# Epoch 06974: val_acc did not improve from 0.88000
# Epoch 6975/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1319 - acc: 0.9531 - val_loss: 0.6905 - val_acc: 0.7400
#
# Epoch 06975: val_acc did not improve from 0.88000
# Epoch 6976/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0963 - acc: 0.9576 - val_loss: 0.6880 - val_acc: 0.7400
#
# Epoch 06976: val_acc did not improve from 0.88000
# Epoch 6977/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.0757 - acc: 0.9688 - val_loss: 0.6888 - val_acc: 0.7400
#
# Epoch 06977: val_acc did not improve from 0.88000
# Epoch 6978/9000
# 448/448 [==============================] - 0s 194us/step - loss: 0.1056 - acc: 0.9643 - val_loss: 0.6932 - val_acc: 0.7400
#
# Epoch 06978: val_acc did not improve from 0.88000
# Epoch 6979/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1032 - acc: 0.9531 - val_loss: 0.6823 - val_acc: 0.7400
#
# Epoch 06979: val_acc did not improve from 0.88000
# Epoch 6980/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0953 - acc: 0.9621 - val_loss: 0.6834 - val_acc: 0.7400
#
# Epoch 06980: val_acc did not improve from 0.88000
# Epoch 6981/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1077 - acc: 0.9598 - val_loss: 0.6856 - val_acc: 0.7400
#
# Epoch 06981: val_acc did not improve from 0.88000
# Epoch 6982/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0968 - acc: 0.9621 - val_loss: 0.6891 - val_acc: 0.7400
#
# Epoch 06982: val_acc did not improve from 0.88000
# Epoch 6983/9000
# 448/448 [==============================] - 0s 197us/step - loss: 0.0998 - acc: 0.9665 - val_loss: 0.6826 - val_acc: 0.7800
#
# Epoch 06983: val_acc did not improve from 0.88000
# Epoch 6984/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1063 - acc: 0.9531 - val_loss: 0.6852 - val_acc: 0.7400
#
# Epoch 06984: val_acc did not improve from 0.88000
# Epoch 6985/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.0900 - acc: 0.9710 - val_loss: 0.6900 - val_acc: 0.7400
#
# Epoch 06985: val_acc did not improve from 0.88000
# Epoch 6986/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.1370 - acc: 0.9509 - val_loss: 0.6965 - val_acc: 0.7400
#
# Epoch 06986: val_acc did not improve from 0.88000
# Epoch 6987/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1157 - acc: 0.9531 - val_loss: 0.6905 - val_acc: 0.7400
#
# Epoch 06987: val_acc did not improve from 0.88000
# Epoch 6988/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1282 - acc: 0.9554 - val_loss: 0.6866 - val_acc: 0.7600
#
# Epoch 06988: val_acc did not improve from 0.88000
# Epoch 6989/9000
# 448/448 [==============================] - 0s 195us/step - loss: 0.0959 - acc: 0.9576 - val_loss: 0.6931 - val_acc: 0.7400
#
# Epoch 06989: val_acc did not improve from 0.88000
# Epoch 6990/9000
# 448/448 [==============================] - 0s 196us/step - loss: 0.1296 - acc: 0.9397 - val_loss: 0.6960 - val_acc: 0.7200
#
# Epoch 06990: val_acc did not improve from 0.88000
# Epoch 6991/9000
# 448/448 [==============================] - 0s 204us/step - loss: 0.0927 - acc: 0.9665 - val_loss: 0.6966 - val_acc: 0.7400
#
# Epoch 06991: val_acc did not improve from 0.88000
# Epoch 6992/9000
# 448/448 [==============================] - 0s 211us/step - loss: 0.0652 - acc: 0.9821 - val_loss: 0.6947 - val_acc: 0.7400
#
# Epoch 06992: val_acc did not improve from 0.88000
# Epoch 6993/9000
# 448/448 [==============================] - 0s 215us/step - loss: 0.1093 - acc: 0.9598 - val_loss: 0.6868 - val_acc: 0.7400
#
# Epoch 06993: val_acc did not improve from 0.88000
# Epoch 6994/9000
# 256/448 [================>.............] - ETA: 0s - loss: 0.1246 - acc: 0.9453
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-97ede973d89d> in <module>
#       7 checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max',save_weights_only=False)
#       8 callback_list = [checkpoint]
# ----> 9 model.fit(x=X_train,y=y_train,validation_data=(X_val,y_val), epochs=9000, callbacks=callback_list, batch_size=16)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     210                         val_outs = test_loop(model, val_f, val_ins,
#     211                                              batch_size=batch_size,
# --> 212                                              verbose=0)
#     213                         val_outs = to_list(val_outs)
#     214                         # Same labels assumed.
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps)
#     390                 ins_batch[i] = ins_batch[i].toarray()
#     391
# --> 392             batch_outs = f(ins_batch)
#     393             if isinstance(batch_outs, list):
#     394                 if batch_index == 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model = load_model("model_21.h5")
get_flatten_layer_output = K.function([model.layers[0].input],
                                  [model.layers[16].output])

# %%
X_test = np.load('new_X_test.npy')
y_test = np.load('test_labels.npy')

final_model = load_model("model_21.h5")

scores_train = final_model.evaluate(X_train, y_train, verbose=0)
print("train result : %s: %.2f%%" % (final_model.metrics_names[1], scores_train[1]*100))

scores_val = final_model.evaluate(X_val, y_val, verbose=0)
print("validation result : %s: %.2f%%" % (final_model.metrics_names[1], scores_val[1]*100))

scores_test = final_model.evaluate(X_test[:,starting_channel:end_index,:], y_test, verbose=0)
print("test result : %s: %.2f%%" % (final_model.metrics_names[1], scores_test[1]*100))
# Out:
# train result : acc: 94.42%
# validation result : acc: 88.00%
# test result : acc: 78.26%

# %%
#transform train and test instances to the new space induces by cnn
## 1 cause we want to test, so dropout will be off
X_test = np.load('new_X_test.npy')
y_test = np.load('test_labels.npy')
X_train_tranformed = get_flatten_layer_output([X_train[:,:,:],1])[0]
X_test_tranformed = get_flatten_layer_output([X_test[:,:,:],1])[0]
print(X_train_tranformed.shape)
print(X_test_tranformed.shape)
# Out:
# (448, 50)
# (161, 50)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

#clf = SVC(C=800,kernel='rbf')
#clf = RandomForestClassifier() 

clf.fit(X_train_tranformed,y_train)
predictions = clf.predict(X_test_tranformed)

accuracy = accuracy_score(y_true=y_test,y_pred=predictions)

print(accuracy)
# Out:
# 0.7763975155279503
# /home/learning/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# now let's evaluate on model 3 using independent test set
X_test = np.load('X_test.npy')
y_test = np.load('test_labels.npy')

final_model = load_model("model_21.h5")
scores = final_model.evaluate(X_test[:,starting_channel:end_index,:], y_test, verbose=0)
print("%s: %.2f%%" % (final_model.metrics_names[1], scores[1]*100))
# Out:
# acc: 74.53%

# %%
from keras.models import load_model

final_model = load_model("model_23.h5")
scores = final_model.evaluate(X_val_3, y_val, verbose=0)
print("%s: %.2f%%" % (final_model.metrics_names[1], scores[1]*100))
# Out:
# acc: 88.00%

# %%
# now let's evaluate on model 3 using independent test set
X_test = np.load('X_test.npy')
y_test = np.load('test_labels.npy')

final_model = load_model("model_25.h5")
scores = final_model.evaluate(X_test[:,4:6,:], y_test, verbose=0)
print("%s: %.2f%%" % (final_model.metrics_names[1], scores[1]*100))
# Out:
# acc: 77.44%
